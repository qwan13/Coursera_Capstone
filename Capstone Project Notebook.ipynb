# %% [markdown]
# # Data Science Capstone – the battle of neighborhood – does living in downtown work for everyone?

# %% [markdown]
# ## Introduction/Business Problem

# %% [markdown]
# Toronto is not only considered as one of the biggest cities in Canada but also famous for its growing number of immigration recently. One of the most important things that the immigrants consider is where they are going to live. There are a lot of advantages of living in the downtown such as the convenient access to cultural grocery stores, social places and even offices. However, it always comes with the excessively expensive rent or house price. Therefore, my business problem is “does living in downtown area work for everyone?” In other words, is convenience worth of the high price? As more people move away from the city center, is it possible that there are not many venues that are essential for living in the downtown?

# %% [markdown]
# ## Data Prepraration

# %% [markdown]
# The analysis utilizes the information of postal codes, borough and neighborhood of Toronto from Wikipedia, given in week 3 assignment. The coordinates of each borough are generated by the python geometry library.
# https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M
#
# Foursquare API is utilized to give information on nearby venues of downtown Toronto, which shows if downtown is suitable for new residents.
#
# The house prices are difficult to gather without company data. The collected data is applied with the data from house retail websites.

# %% [markdown]
# ## Methodology

# %% [markdown]
# All project-related materials are published on Github. The master data was collected from Wikipedia page and was cleaned using python. The master data was expended by geometry library of latitude and longitude.
# The complete dataset is shown as following.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Since we are only focusing on Downtown Toronto, we filter the dataframe to show only the ones that match the need. Then we use the python folium library to map the downtown.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Then I used Foursquare API to find the nearby venues of the given locations. It generated 100 venues within 500 radius of downtown. All venues are organized by category and displayed in the table.
# ![image.png](attachment:image.png)

# %% [markdown]
# The top 3 categoties are coffee shops, clothing stores and hotels.

# %% [markdown]
# The one hot encoding was utilized to find the most common venue nearby of a given location. We only include the most 10 common ones.
# ![image.png](attachment:image.png)

# %% [markdown]
# I used Kmeans to cluster the neighborhood into three clusters. Each cluster has their most common venues as following:
# <br> Cluster 0: Coffee Shops
# <br> Cluster 1: Parks
# <br> Cluster 2: Grocery Store
# <br>
# ![image.png](attachment:image.png)

# %% [markdown]
# The renting websites suggest the average rent for apartments in downtown toronto. The average rent was shown based on clusters as the in the graph.
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Results

# %% [markdown]
# The graphs demonstrate that downtown toronto has a lot of social venues such as coffee shops,clothing stores and hotels which are not neccessary for daily living. The rent of the city center is also excessively higher. Cluster 0 and cluster 1 are not perfect to live in and we found that cluster 2 (Christie) which is relatively outer from the city is suitable for living. There are gorcery stores and restaurants in Christie and rent is relatively cheaper.

# %% [markdown]
# ## Discussion

# %% [markdown]
# Based on the results and findings, it is clear that downtown toronto is more of a social center instead of a living center. Living in downtown costs a lot but also is not very convenient for new residents. Downtown is more a place for work and social events. Living in downtown is not that convenient as most people think. As it gets more and more crowded, downtown becomes less and less comfortable to live in.

# %% [markdown]
# ## Conclusion & Future

# %% [markdown]
# It seems like living in downtown does not work for people who are more family-oriented. It might work for working professionals who spend much time working in their offices and are able to afford the high rent. For new immigrant families, it is more suitable to find a place away from downtown but with big space.
# <br> This research methodology can be used to solve a lot of problems in the future. For example, a business owner wants to open a new restaurant in toronto. Python data science tools are so strong that they scrape and find data automatically and save much time. They turn raw data into useful, clean and visualized data. The further findings should be very helpful in making business decisions for clients or companies themselves.
#
# <br> For images, please see https://dataplatform.cloud.ibm.com/analytics/notebooks/v2/04e1fe24-3648-4282-8934-c335914593e0?projectid=edf55cea-6879-417a-b726-72a6e24e8859&context=cpdaas
